# %% [markdown]
# <img src="attachment:1b19e88c-5564-4c02-ad91-fd13dd43e31d.png">
#
# ## 1. Importation des bibliothèques Python

# %%
# audio signal analysis
import librosa
import librosa.display as lplt

# command shell for interactive computing
import IPython

# display graphs
import matplotlib.pyplot as plt

# matrices or multidimensional arrays handling 
import numpy as np

# data handling and analysis
import pandas as pd

# data preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# define and train an AI model
import keras
import tensorflow as tf
from tensorflow.keras.models import Sequential

# %% [markdown]
# ## 2. Test sur un son

# %%
test_sound = "/workspace/data/audios/AtlanticSpottedDolphin/61025001.wav"

# %% [markdown]
# - Chargement et décodage du son

# %%
data, sr = librosa.load(test_sound)
print(type(data), type(sr))
# Out:
# <class 'numpy.ndarray'> <class 'int'>

# %%
librosa.load(test_sound ,sr = 45600)
# Out:
# (array([-0.0739522 , -0.06588229, -0.06673266, ...,  0.03021295,
#          0.05592792,  0.        ], dtype=float32),
#  45600)

# %% [markdown]
# - Jouer un son avec IPython.display.Audio

# %%
IPython.display.Audio(data, rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 3. Prétraitement des données
#
# ### a. Fichier `data.csv`

# %%
df = pd.read_csv('/workspace/data/data.csv')
df.head()
# Out:
#        filename    length  chroma_stft_mean  chroma_stft_var     rms_mean  \
# 0  6102603E.wav  0.426664          0.042434      5157.104325  3101.100191
# 1  61026030.wav  0.434773          0.053204      5594.399169  2860.406861
# 2  61026048.wav  0.432415          0.042047      5135.238139  2982.555668
# 3  6102603I.wav  0.438314          0.076127      5803.472083  3099.706089
# 4  61026047.wav  0.416906          0.081022      5043.428899  2982.812198
#
#        rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  8617.587891                0.356964            -241.481033
# 1  8655.933556                0.434289            -228.107635
# 2  8378.181032                0.365667            -244.113342
# 3  9038.656456                0.414833            -198.311844
# 4  8271.866648                0.322625            -234.926605
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...      tempo  \
# 0                24.920166               48.238968  ...  13.670743
# 1                -4.825935               60.204544  ...  11.302414
# 2                12.709079               48.617630  ...  15.568404
# 3                 0.518129               47.096676  ...  15.731695
# 4                12.705063               54.443558  ...  15.146926
#
#    mfcc1_mean  mfcc1_var  mfcc2_mean  mfcc2_var  mfcc3_mean  mfcc3_var  \
# 0   -0.705876  12.712521    1.321301  10.524447    0.343317   6.712308
# 1    2.397469  13.868607   -2.265396  11.323673    0.582180   6.923624
# 2   -2.544822  10.559988   -0.473371   8.464706    0.382612   6.677320
# 3    0.987929  16.382414   -0.967779   8.810925    1.867840   9.033828
# 4    1.311773  13.756646   -0.811321   8.872554    3.451088   6.508763
#
#    mfcc4_mean  mfcc4_var                   label
# 0    0.371731   1.841404  AtlanticSpottedDolphin
# 1   -2.080763   1.947379  AtlanticSpottedDolphin
# 2    2.163096   3.520124  AtlanticSpottedDolphin
# 3    2.434472   3.793100  AtlanticSpottedDolphin
# 4   -0.489402   4.719871  AtlanticSpottedDolphin
#
# [5 rows x 28 columns]

# %%
# dataframe types
df.dtypes
# Out:
# filename                    object
# length                     float64
# chroma_stft_mean           float64
# chroma_stft_var            float64
# rms_mean                   float64
# rms_var                    float64
# spectral_centroid_mean     float64
# spectral_centroid_var      float64
# spectral_bandwidth_mean    float64
# spectral_bandwidth_var     float64
# rolloff_mean               float64
# rolloff_var                float64
# zero_crossing_rate_mean    float64
# zero_crossing_rate_var     float64
# harmony_mean               float64
# harmony_var                float64
# perceptr_mean              float64
# perceptr_var               float64
# tempo                      float64
# mfcc1_mean                 float64
# mfcc1_var                  float64
# mfcc2_mean                 float64
# mfcc2_var                  float64
# mfcc3_mean                 float64
# mfcc3_var                  float64
# mfcc4_mean                 float64
# mfcc4_var                  float64
# label                       object
# dtype: object

# %% [markdown]
# ### b. Extraction des caractéristiques
#
# - Extraction de caractéristiques (nécessaire avant de lancer l'entraînement)
# - Objectif : définir les **entrées** et **sorties** du réseau neuronal
#
# - **SORTIE** (y) : dernière colonne qui est le `label`.
#
# Nous ne pouvons pas utiliser directement du texte pour l'entraînement => nous allons encoder ces labels avec la fonction **LabelEncoder()** de **sklearn.preprocessing**.
#
# Avant de pouvoir exécuter un modèle, nous devons convertir ce type de données textuelles catégorielles en données numériques que le modèle peut comprendre.

# %%
class_list = df.iloc[:,-1]
encoder = LabelEncoder()
y = encoder.fit_transform(class_list)
print("y: ", y)
# Out:
# y:  [ 0  0  0 ... 44 44 44]

# %% [markdown]
# - **INPUTS** (X) : toutes les autres colonnes sont des paramètres d'entrée du réseau neuronal, sauf le nom de fichier.
#
# Nous supprimons la première colonne qui ne fournit aucune information pour l'apprentissage (le nom de fichier) et la dernière qui correspond à la sortie.

# %%
input_parameters = df.iloc[:, 1:27]
scaler = StandardScaler()
X = scaler.fit_transform(np.array(input_parameters))
print("X:", X)
# Out:
# X: [[-0.71758759  0.20419758  1.17840861 ...  0.59678504  0.59680033
#   -0.43635211]
#  [-0.66140594  0.48716815  1.44344394 ...  0.6360472   0.11020783
#   -0.41656124]
#  [-0.67774188  0.19402336  1.16515597 ...  0.59028425  0.95222009
#   -0.12285259]
#  ...
#  [-1.00584499  1.27000953  0.84831611 ...  0.55786759 -0.3320992
#    0.63891663]
#  [-0.26724693  0.69987104 -0.84229563 ...  0.42982227  0.82545802
#    0.16668007]
#  [ 1.77048234 -0.63530507  0.03279294 ...  0.70826513  0.53040824
#    0.66172722]]

# %% [markdown]
# ## 4. Séparation des données pour l'entraînement

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# # Construction du modèle
#
# La première étape consiste à construire le modèle et à afficher le résumé.
#
# Pour le modèle CNN...
# - toutes les couches cachées utilisent une fonction d'activation **ReLU**.
# - la couche de sortie utilise une fonction **Softmax**.
# - un **Dropout** est utilisé pour éviter l'overfitting.
#
# <img src="attachment:0307dc5e-7b6f-4614-857c-f39c731e4b5f.png">

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(512, activation = 'relu', input_shape = (X_train.shape[1],)),
    tf.keras.layers.Dropout(0.2),
    
    tf.keras.layers.Dense(256, activation = 'relu'),
    keras.layers.Dropout(0.2),
    
    tf.keras.layers.Dense(128, activation = 'relu'),
    tf.keras.layers.Dropout(0.2),
    
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dropout(0.2),
    
    tf.keras.layers.Dense(45, activation = 'softmax'),
])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               13824
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 45)                2925
# =================================================================
# Total params: 189,229
# Trainable params: 189,229
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## 5. Entraînement et évaluation du modèle
#
# L'optimiseur **Adam** est utilisé pour entraîner le modèle sur 100 époques. Ce choix a été fait car il nous permet d'obtenir de meilleurs résultats.
#
# - Calcul de la perte avec la fonction **sparse_categorical_crossentropy**

# %%
def trainModel(model,epochs, optimizer):
    batch_size = 128
    model.compile(optimizer = optimizer, loss = 'sparse_categorical_crossentropy', metrics = 'accuracy')
    return model.fit(X_train, y_train, validation_data = (X_val, y_val), epochs = epochs, batch_size = batch_size)

# %% [markdown]
# - Lancement de l'entraînement :

# %%
model_history = trainModel(model = model, epochs = 100, optimizer = 'adam')
# Out:
# Epoch 1/100
# 79/79 [==============================] - 2s 12ms/step - loss: 2.7538 - accuracy: 0.3312 - val_loss: 1.2640 - val_accuracy: 0.6442
# Epoch 2/100
# 79/79 [==============================] - 0s 5ms/step - loss: 1.3369 - accuracy: 0.6302 - val_loss: 0.8895 - val_accuracy: 0.7505
# Epoch 3/100
# 79/79 [==============================] - 0s 6ms/step - loss: 1.0093 - accuracy: 0.7155 - val_loss: 0.7043 - val_accuracy: 0.7979
# Epoch 4/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.8095 - accuracy: 0.7659 - val_loss: 0.5942 - val_accuracy: 0.8333
# Epoch 5/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.6919 - accuracy: 0.7954 - val_loss: 0.5193 - val_accuracy: 0.8536
# Epoch 6/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.6071 - accuracy: 0.8224 - val_loss: 0.4766 - val_accuracy: 0.8611
# Epoch 7/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.5547 - accuracy: 0.8335 - val_loss: 0.4218 - val_accuracy: 0.8743
# Epoch 8/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.4953 - accuracy: 0.8562 - val_loss: 0.3932 - val_accuracy: 0.8846
# Epoch 9/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.4683 - accuracy: 0.8630 - val_loss: 0.3654 - val_accuracy: 0.8910
# Epoch 10/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.4101 - accuracy: 0.8816 - val_loss: 0.3307 - val_accuracy: 0.9017
# Epoch 11/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.3782 - accuracy: 0.8845 - val_loss: 0.3151 - val_accuracy: 0.9073
# Epoch 12/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.3619 - accuracy: 0.8939 - val_loss: 0.3050 - val_accuracy: 0.9073
# Epoch 13/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.3482 - accuracy: 0.8967 - val_loss: 0.3070 - val_accuracy: 0.9081
# Epoch 14/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.3345 - accuracy: 0.9005 - val_loss: 0.2899 - val_accuracy: 0.9101
# Epoch 15/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.3197 - accuracy: 0.9022 - val_loss: 0.2788 - val_accuracy: 0.9196
# Epoch 16/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.3095 - accuracy: 0.9040 - val_loss: 0.2722 - val_accuracy: 0.9200
# Epoch 17/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2754 - accuracy: 0.9172 - val_loss: 0.2610 - val_accuracy: 0.9200
# Epoch 18/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2716 - accuracy: 0.9160 - val_loss: 0.2554 - val_accuracy: 0.9244
# Epoch 19/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2543 - accuracy: 0.9222 - val_loss: 0.2574 - val_accuracy: 0.9216
# Epoch 20/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2460 - accuracy: 0.9210 - val_loss: 0.2475 - val_accuracy: 0.9184
# Epoch 21/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2394 - accuracy: 0.9199 - val_loss: 0.2387 - val_accuracy: 0.9224
# Epoch 22/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2262 - accuracy: 0.9301 - val_loss: 0.2410 - val_accuracy: 0.9220
# Epoch 23/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2196 - accuracy: 0.9316 - val_loss: 0.2384 - val_accuracy: 0.9300
# Epoch 24/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2073 - accuracy: 0.9327 - val_loss: 0.2302 - val_accuracy: 0.9296
# Epoch 25/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2098 - accuracy: 0.9296 - val_loss: 0.2241 - val_accuracy: 0.9300
# Epoch 26/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1882 - accuracy: 0.9354 - val_loss: 0.2162 - val_accuracy: 0.9288
# Epoch 27/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1948 - accuracy: 0.9377 - val_loss: 0.2279 - val_accuracy: 0.9260
# Epoch 28/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1778 - accuracy: 0.9407 - val_loss: 0.2197 - val_accuracy: 0.9335
# Epoch 29/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1874 - accuracy: 0.9364 - val_loss: 0.2184 - val_accuracy: 0.9339
# Epoch 30/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1824 - accuracy: 0.9432 - val_loss: 0.2091 - val_accuracy: 0.9308
# Epoch 31/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1651 - accuracy: 0.9456 - val_loss: 0.2208 - val_accuracy: 0.9339
# Epoch 32/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1617 - accuracy: 0.9423 - val_loss: 0.2030 - val_accuracy: 0.9347
# Epoch 33/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1542 - accuracy: 0.9509 - val_loss: 0.2012 - val_accuracy: 0.9351
# Epoch 34/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1667 - accuracy: 0.9449 - val_loss: 0.2200 - val_accuracy: 0.9308
# Epoch 35/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1585 - accuracy: 0.9428 - val_loss: 0.2179 - val_accuracy: 0.9367
# Epoch 36/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1598 - accuracy: 0.9455 - val_loss: 0.2272 - val_accuracy: 0.9335
# Epoch 37/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1554 - accuracy: 0.9471 - val_loss: 0.2043 - val_accuracy: 0.9391
# Epoch 38/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1404 - accuracy: 0.9554 - val_loss: 0.2126 - val_accuracy: 0.9391
# Epoch 39/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1514 - accuracy: 0.9481 - val_loss: 0.2029 - val_accuracy: 0.9391
# Epoch 40/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1337 - accuracy: 0.9528 - val_loss: 0.2002 - val_accuracy: 0.9387
# Epoch 41/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1281 - accuracy: 0.9554 - val_loss: 0.2101 - val_accuracy: 0.9387
# Epoch 42/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1316 - accuracy: 0.9557 - val_loss: 0.2296 - val_accuracy: 0.9339
# Epoch 43/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1259 - accuracy: 0.9518 - val_loss: 0.2127 - val_accuracy: 0.9331
# Epoch 44/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1274 - accuracy: 0.9548 - val_loss: 0.2073 - val_accuracy: 0.9427
# Epoch 45/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1209 - accuracy: 0.9556 - val_loss: 0.2036 - val_accuracy: 0.9407
# Epoch 46/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1312 - accuracy: 0.9529 - val_loss: 0.2169 - val_accuracy: 0.9347
# Epoch 47/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1237 - accuracy: 0.9559 - val_loss: 0.2081 - val_accuracy: 0.9403
# Epoch 48/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1226 - accuracy: 0.9581 - val_loss: 0.2050 - val_accuracy: 0.9419
# Epoch 49/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1236 - accuracy: 0.9552 - val_loss: 0.2124 - val_accuracy: 0.9367
# Epoch 50/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1234 - accuracy: 0.9563 - val_loss: 0.2012 - val_accuracy: 0.9447
# Epoch 51/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1103 - accuracy: 0.9589 - val_loss: 0.2032 - val_accuracy: 0.9395
# Epoch 52/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1091 - accuracy: 0.9591 - val_loss: 0.2173 - val_accuracy: 0.9379
# Epoch 53/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1162 - accuracy: 0.9586 - val_loss: 0.2020 - val_accuracy: 0.9395
# Epoch 54/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1116 - accuracy: 0.9597 - val_loss: 0.2045 - val_accuracy: 0.9399
# Epoch 55/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1133 - accuracy: 0.9607 - val_loss: 0.2049 - val_accuracy: 0.9431
# Epoch 56/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1038 - accuracy: 0.9619 - val_loss: 0.1982 - val_accuracy: 0.9415
# Epoch 57/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1033 - accuracy: 0.9608 - val_loss: 0.1906 - val_accuracy: 0.9427
# Epoch 58/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0987 - accuracy: 0.9626 - val_loss: 0.2076 - val_accuracy: 0.9407
# Epoch 59/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1027 - accuracy: 0.9647 - val_loss: 0.1936 - val_accuracy: 0.9447
# Epoch 60/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0940 - accuracy: 0.9637 - val_loss: 0.2280 - val_accuracy: 0.9363
# Epoch 61/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1001 - accuracy: 0.9621 - val_loss: 0.2107 - val_accuracy: 0.9407
# Epoch 62/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1093 - accuracy: 0.9603 - val_loss: 0.2049 - val_accuracy: 0.9411
# Epoch 63/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0974 - accuracy: 0.9638 - val_loss: 0.2041 - val_accuracy: 0.9419
# Epoch 64/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1054 - accuracy: 0.9626 - val_loss: 0.2058 - val_accuracy: 0.9431
# Epoch 65/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1075 - accuracy: 0.9594 - val_loss: 0.1999 - val_accuracy: 0.9447
# Epoch 66/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1010 - accuracy: 0.9619 - val_loss: 0.2103 - val_accuracy: 0.9415
# Epoch 67/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0860 - accuracy: 0.9649 - val_loss: 0.2180 - val_accuracy: 0.9399
# Epoch 68/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0965 - accuracy: 0.9630 - val_loss: 0.2074 - val_accuracy: 0.9431
# Epoch 69/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0858 - accuracy: 0.9668 - val_loss: 0.2101 - val_accuracy: 0.9407
# Epoch 70/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0977 - accuracy: 0.9642 - val_loss: 0.2039 - val_accuracy: 0.9411
# Epoch 71/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1017 - accuracy: 0.9632 - val_loss: 0.2029 - val_accuracy: 0.9455
# Epoch 72/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0880 - accuracy: 0.9652 - val_loss: 0.1896 - val_accuracy: 0.9447
# Epoch 73/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1008 - accuracy: 0.9605 - val_loss: 0.2001 - val_accuracy: 0.9451
# Epoch 74/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0925 - accuracy: 0.9669 - val_loss: 0.1927 - val_accuracy: 0.9431
# Epoch 75/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0833 - accuracy: 0.9672 - val_loss: 0.1990 - val_accuracy: 0.9435
# Epoch 76/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0866 - accuracy: 0.9648 - val_loss: 0.2165 - val_accuracy: 0.9427
# Epoch 77/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0893 - accuracy: 0.9676 - val_loss: 0.2143 - val_accuracy: 0.9431
# Epoch 78/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0900 - accuracy: 0.9614 - val_loss: 0.2176 - val_accuracy: 0.9387
# Epoch 79/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0930 - accuracy: 0.9654 - val_loss: 0.2101 - val_accuracy: 0.9407
# Epoch 80/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0830 - accuracy: 0.9677 - val_loss: 0.2069 - val_accuracy: 0.9419
# Epoch 81/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0928 - accuracy: 0.9664 - val_loss: 0.2066 - val_accuracy: 0.9415
# Epoch 82/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0775 - accuracy: 0.9685 - val_loss: 0.2058 - val_accuracy: 0.9411
# Epoch 83/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0888 - accuracy: 0.9652 - val_loss: 0.2178 - val_accuracy: 0.9387
# Epoch 84/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0854 - accuracy: 0.9677 - val_loss: 0.2056 - val_accuracy: 0.9431
# Epoch 85/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0907 - accuracy: 0.9653 - val_loss: 0.2099 - val_accuracy: 0.9407
# Epoch 86/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0797 - accuracy: 0.9689 - val_loss: 0.2098 - val_accuracy: 0.9435
# Epoch 87/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0794 - accuracy: 0.9691 - val_loss: 0.2141 - val_accuracy: 0.9391
# Epoch 88/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0783 - accuracy: 0.9670 - val_loss: 0.2284 - val_accuracy: 0.9399
# Epoch 89/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0723 - accuracy: 0.9699 - val_loss: 0.2081 - val_accuracy: 0.9415
# Epoch 90/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0726 - accuracy: 0.9708 - val_loss: 0.2202 - val_accuracy: 0.9459
# Epoch 91/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0906 - accuracy: 0.9673 - val_loss: 0.2138 - val_accuracy: 0.9423
# Epoch 92/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0899 - accuracy: 0.9658 - val_loss: 0.2092 - val_accuracy: 0.9431
# Epoch 93/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0840 - accuracy: 0.9653 - val_loss: 0.2044 - val_accuracy: 0.9431
# Epoch 94/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0736 - accuracy: 0.9683 - val_loss: 0.2211 - val_accuracy: 0.9391
# Epoch 95/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0773 - accuracy: 0.9685 - val_loss: 0.2166 - val_accuracy: 0.9415
# Epoch 96/100
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0814 - accuracy: 0.9662 - val_loss: 0.2238 - val_accuracy: 0.9443
# Epoch 97/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0783 - accuracy: 0.9684 - val_loss: 0.2156 - val_accuracy: 0.9427
# Epoch 98/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0848 - accuracy: 0.9683 - val_loss: 0.2171 - val_accuracy: 0.9439
# Epoch 99/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0806 - accuracy: 0.9693 - val_loss: 0.2085 - val_accuracy: 0.9411
# Epoch 100/100
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0688 - accuracy: 0.9731 - val_loss: 0.2077 - val_accuracy: 0.9459

# %% [markdown]
# - Affichage de la courbe de perte - **loss** :

# %%
loss_train_curve = model_history.history["loss"]
loss_val_curve = model_history.history["val_loss"]
plt.plot(loss_train_curve, label = "Train")
plt.plot(loss_val_curve, label = "Validation")
plt.legend(loc = 'upper right')
plt.title("Loss")
plt.show()

# %% [markdown]
# - Affichage des courbes de précision - **accuracy** :

# %%
acc_train_curve = model_history.history["accuracy"]
acc_val_curve = model_history.history["val_accuracy"]
plt.plot(acc_train_curve, label = "Train")
plt.plot(acc_val_curve, label = "Validation")
plt.legend(loc = 'lower right')
plt.title("Accuracy")
plt.show()

# %%
test_loss, test_acc = model.evaluate(X_val, y_val, batch_size = 128)
print("The test loss is: ", test_loss)
print("The best accuracy is: ", test_acc*100)
# Out:
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2077 - accuracy: 0.9459
# The test loss is:  0.20774847269058228
# The best accuracy is:  94.58814263343811

# %% [markdown]
# ## 7. Exporter le modèle pour une future inférence

# %%
model.save('/workspace/ai-model/model-marine-mammal-sounds-classification')
# Out:
# INFO:tensorflow:Assets written to: /workspace/ai-model/model-marine-mammal-sounds-classification/assets

# %%
# my_model directory
# %ls /workspace/ai-model/model-marine-mammal-sounds-classification
# Out:
# assets/  saved_model.pb  variables/

# %%
model = tf.keras.models.load_model('/workspace/ai-model/model-marine-mammal-sounds-classification')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               13824
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 45)                2925
# =================================================================
# Total params: 189,229
# Trainable params: 189,229
# Non-trainable params: 0
# _________________________________________________________________
